# %%
# !pip install plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
import plotly.express as px

# %%
warnings.filterwarnings('ignore')

# %%
df_pais = pd.read_csv('continents2.csv')

# %%
df_pais
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
# ...

# %%
df_pais.rename(columns = {'alpha-3':'Code'},inplace=True)

# %%
sub = df_pais[['Code','region','sub-region']]

# %% [markdown]
# Produção

# %%
df_prod_renov = pd.read_csv('modern-renewable-prod.csv')

# %%
df_prod_renov
# Out:
#            Entity Code  Year  Electricity from wind (TWh)  \
# 0     Afghanistan  AFG  2000                          0.0
# 1     Afghanistan  AFG  2001                          0.0
# 2     Afghanistan  AFG  2002                          0.0
# 3     Afghanistan  AFG  2003                          0.0
# 4     Afghanistan  AFG  2004                          0.0
# ...           ...  ...   ...                          ...
# 7990     Zimbabwe  ZWE  2016                          0.0
# 7991     Zimbabwe  ZWE  2017                          0.0
# 7992     Zimbabwe  ZWE  2018                          0.0
# 7993     Zimbabwe  ZWE  2019                          0.0
# 7994     Zimbabwe  ZWE  2020                          0.0
#
#       Electricity from hydro (TWh)  Electricity from solar (TWh)  \
# 0                             0.31                          0.00
# 1                             0.50                          0.00
# 2                             0.56                          0.00
# ...

# %%
nome_coluna = {
    'Entity':'Pais',
    'Year':'Ano',
    'Electricity from wind (TWh)': 'Eolica',
    'Electricity from hydro (TWh)':'Hidroeletrica',
    'Electricity from solar (TWh)':'Solar',
    'Electricity from other renewables including bioenergy (TWh)':'Outras Fontes'
}

# %%
df_prod_renov.rename(columns=nome_coluna,inplace=True)

# %%
df_prod_renov
# Out:
#              Pais Code   Ano  Eolica  Hidroeletrica  Solar  Outras Fontes
# 0     Afghanistan  AFG  2000     0.0           0.31   0.00           0.00
# 1     Afghanistan  AFG  2001     0.0           0.50   0.00           0.00
# 2     Afghanistan  AFG  2002     0.0           0.56   0.00           0.00
# 3     Afghanistan  AFG  2003     0.0           0.63   0.00           0.00
# 4     Afghanistan  AFG  2004     0.0           0.56   0.00           0.00
# ...           ...  ...   ...     ...            ...    ...            ...
# 7990     Zimbabwe  ZWE  2016     0.0           2.95   0.01           0.36
# 7991     Zimbabwe  ZWE  2017     0.0           3.93   0.01           0.32
# 7992     Zimbabwe  ZWE  2018     0.0           5.00   0.01           0.39
# 7993     Zimbabwe  ZWE  2019     0.0           7.26   0.01           0.38
# 7994     Zimbabwe  ZWE  2020     0.0           7.26   0.01           0.38
#
# [7995 rows x 7 columns]

# %%
producao_energia = pd.merge(df_prod_renov, sub, on='Code', how='inner')

# %%
producao_energia
# Out:
#              Pais Code   Ano  Eolica  Hidroeletrica  Solar  Outras Fontes  \
# 0     Afghanistan  AFG  2000     0.0           0.31   0.00           0.00
# 1     Afghanistan  AFG  2001     0.0           0.50   0.00           0.00
# 2     Afghanistan  AFG  2002     0.0           0.56   0.00           0.00
# 3     Afghanistan  AFG  2003     0.0           0.63   0.00           0.00
# 4     Afghanistan  AFG  2004     0.0           0.56   0.00           0.00
# ...           ...  ...   ...     ...            ...    ...            ...
# 6935     Zimbabwe  ZWE  2016     0.0           2.95   0.01           0.36
# 6936     Zimbabwe  ZWE  2017     0.0           3.93   0.01           0.32
# 6937     Zimbabwe  ZWE  2018     0.0           5.00   0.01           0.39
# 6938     Zimbabwe  ZWE  2019     0.0           7.26   0.01           0.38
# 6939     Zimbabwe  ZWE  2020     0.0           7.26   0.01           0.38
#
#       region          sub-region
# 0       Asia       Southern Asia
# ...

# %%
producao_energia.to_csv('producao_energia.csv', index=False)

# %%
sub-region
