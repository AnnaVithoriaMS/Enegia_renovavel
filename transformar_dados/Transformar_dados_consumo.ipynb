# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
import plotly.express as px

# %%
df_pais= pd.read_csv('continents2.csv')

# %%
df_pais
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
# ...

# %%
df_pais.rename(columns = {'alpha-3':'Code'},inplace=True)

# %%
sub = df_pais[['Code','region','sub-region']]

# %%
df_pais.columns
# Out:
# Index(['name', 'alpha-2', 'Code', 'country-code', 'iso_3166-2', 'region',
#        'sub-region', 'intermediate-region', 'region-code', 'sub-region-code',
#        'intermediate-region-code'],
#       dtype='object')

# %%
df= pd.read_csv('modern-renewable-energy-consumption.csv')

# %%
df
# Out:
#       Entity      Code  Year  Wind Generation - TWh  Solar Generation - TWh  \
# 0     Africa       NaN  1965               0.000000                0.000000
# 1     Africa       NaN  1966               0.000000                0.000000
# 2     Africa       NaN  1967               0.000000                0.000000
# 3     Africa       NaN  1968               0.000000                0.000000
# 4     Africa       NaN  1969               0.000000                0.000000
# ...      ...       ...   ...                    ...                     ...
# 4998   World  OWID_WRL  2016             962.227395              328.385208
# 4999   World  OWID_WRL  2017            1140.310949              446.054164
# 5000   World  OWID_WRL  2018            1269.520536              576.951248
# 5001   World  OWID_WRL  2019            1418.170046              707.918495
# 5002   World  OWID_WRL  2020            1591.213512              855.724690
#
#       Geo Biomass Other - TWh  Hydro Generation - TWh
# ...

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4219 entries, 56 to 5002
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Entity                   4219 non-null   object
#  1   Code                     4219 non-null   object
#  2   Year                     4219 non-null   int64
#  3   Wind Generation - TWh    4219 non-null   float64
#  4   Solar Generation - TWh   4219 non-null   float64
#  5   Geo Biomass Other - TWh  4219 non-null   float64
#  6   Hydro Generation - TWh   4219 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 263.7+ KB

# %%
df['Code'].unique()
# Out:
# array(['DZA', 'ARG', 'AUS', 'AUT', 'AZE', 'BGD', 'BLR', 'BEL', 'BRA',
#        'BGR', 'CAN', 'CHL', 'CHN', 'COL', 'HRV', 'CYP', 'CZE', 'DNK',
#        'ECU', 'EGY', 'EST', 'FIN', 'FRA', 'DEU', 'GRC', 'HKG', 'HUN',
#        'ISL', 'IND', 'IDN', 'IRN', 'IRQ', 'IRL', 'ISR', 'ITA', 'JPN',
#        'KAZ', 'KWT', 'LVA', 'LTU', 'LUX', 'MYS', 'MEX', 'MAR', 'NLD',
#        'NZL', 'MKD', 'NOR', 'OMN', 'PAK', 'PER', 'PHL', 'POL', 'PRT',
#        'QAT', 'ROU', 'RUS', 'SAU', 'SGP', 'SVK', 'SVN', 'ZAF', 'KOR',
#        'ESP', 'LKA', 'SWE', 'CHE', 'TWN', 'THA', 'TTO', 'TUR', 'TKM',
#        'UKR', 'ARE', 'GBR', 'USA', 'UZB', 'VEN', 'VNM', 'OWID_WRL'],
#       dtype=object)

# %%
df = df[df['Code'] != 'OWID_WRL']

# %%
energia = pd.merge(df, sub, on='Code', how='inner')

# %%
energia
# Out:
#        Entity Code  Year  Wind Generation - TWh  Solar Generation - TWh  \
# 0     Algeria  DZA  1965               0.000000                0.000000
# 1     Algeria  DZA  1966               0.000000                0.000000
# 2     Algeria  DZA  1967               0.000000                0.000000
# 3     Algeria  DZA  1968               0.000000                0.000000
# 4     Algeria  DZA  1969               0.000000                0.000000
# ...       ...  ...   ...                    ...                     ...
# 4158  Vietnam  VNM  2016               0.209800                0.006669
# 4159  Vietnam  VNM  2017               0.268292                0.009371
# 4160  Vietnam  VNM  2018               0.310233                0.113493
# 4161  Vietnam  VNM  2019               0.000484                4.117189
# 4162  Vietnam  VNM  2020               0.000779                9.452731
#
#       Geo Biomass Other - TWh  Hydro Generation - TWh  region  \
# ...

# %%
nome_coluna = {
    'Entity':'Pais',
    'Year':'Ano',
    'Wind Generation - TWh': 'Eolica',
    'Hydro Generation - TWh':'Hidroeletrica',
    'Solar Generation - TWh':'Solar',
    'Geo Biomass Other - TWh':'Outras Fontes',
    'region':'Continente',
    'sub-region':'Sub-região'
}

# %%
energia.rename(columns=nome_coluna,inplace=True)

# %%
energia
# Out:
#          Pais Code   Ano    Eolica     Solar  Outras Fontes  Hidroeletrica  \
# 0     Algeria  DZA  1965  0.000000  0.000000       0.000000       0.400000
# 1     Algeria  DZA  1966  0.000000  0.000000       0.000000       0.355000
# 2     Algeria  DZA  1967  0.000000  0.000000       0.000000       0.410000
# 3     Algeria  DZA  1968  0.000000  0.000000       0.000000       0.563000
# 4     Algeria  DZA  1969  0.000000  0.000000       0.000000       0.361000
# ...       ...  ...   ...       ...       ...            ...            ...
# 4158  Vietnam  VNM  2016  0.209800  0.006669       0.068000      66.047574
# 4159  Vietnam  VNM  2017  0.268292  0.009371       0.076454      88.762103
# 4160  Vietnam  VNM  2018  0.310233  0.113493       0.076454      84.485320
# 4161  Vietnam  VNM  2019  0.000484  4.117189       0.000439      67.722484
# 4162  Vietnam  VNM  2020  0.000779  9.452731       0.000410      68.964918
#
#      Continente          Sub-região
# ...

# %%
energia.to_csv('consumo_energia.csv', index=False)
